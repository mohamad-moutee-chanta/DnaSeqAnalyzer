# %% [markdown]
# <a href="https://colab.research.google.com/github/mohamad-moutee-chanta/DnaSeqAnalyzer/blob/main/Biomarker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("googledrive")
library(googledrive)

# %%
drive_auth()

# %%
my_file <- drive_get("Reservoir Dogs/Biomarker Project/GSE227832.txt")

# %%
drive_download(my_file, overwrite = TRUE)

# %%
data <- read.table("GSE227832.txt", header = TRUE)

# %%
controls <- data[, tail(names(data), 10)]
controls

# %%
control_dataframe <- cbind(data[1], controls)
control_dataframe

# %%
colnames(data)

# %%
data[c('Constitutional_458rep3','Constitutional_559rep2','ALL_317_2','ALL_468_2','ALL_358_r',
       'ALL_210_r','ALL_257_r','ALL_555_2','ALL_464_r','ALL_680_2','ALL_380_r','ALL_680_r',
       'ALL_Validation_20','ALL_validation_12','ALL_1026_r','ALL_368_r','ALL_317_3')] <- list(NULL) # remove relapse, validation, techincal replicates etc.

# %%
colnames(data)

# %%
if (!require("BiocManager", quietly = TRUE))
    install.packages("BiocManager")

BiocManager::install("biomaRt")

# %%
library(biomaRt)

# %%
ensembl <- useMart("ensembl",dataset="hsapiens_gene_ensembl")
my_genes <- data[1]
out <- getBM(attributes=c("ensembl_gene_id", "gene_biotype"),
    filters="ensembl_gene_id", values=my_genes, mart=ensembl)

# %%
out

# %%
BiocManager::install("sva")
